# %%
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt
df = pd.read_csv('../../Datasets/socialmedia.csv')
df.head()
# Out:
#    post_id   platform post_type        post_time  likes  comments  shares  \
# 0        1   Facebook     image  8/17/2023 14:45   2121       474     628
# 1        2   Facebook  carousel   5/14/2023 0:45   3660       432     694
# 2        3  Instagram      poll  2/21/2023 16:15   4955       408     688
# 3        4    Twitter     image  11/16/2023 0:45   1183        90     187
# 4        5    Twitter     video   5/23/2023 0:30   3499       247     286
#
#    post_day sentiment_score
# 0  Thursday        positive
# 1    Sunday         neutral
# 2   Tuesday        negative
# 3  Thursday        negative
# 4   Tuesday        positive

# %%
sns.countplot(x='platform' , data=df)
plt.ylabel("Number of Posts")
# Out:
# Text(0, 0.5, 'Number of Posts')

# %%
sns.boxplot(x='sentiment_score' , y='likes' , data = df)
# Out:
# <Axes: xlabel='sentiment_score', ylabel='likes'>

# %%
df.isnull().sum()
# Out:
# post_id            0
# platform           0
# post_type          0
# post_time          0
# likes              0
# comments           0
# shares             0
# post_day           0
# sentiment_score    0
# dtype: int64

# %%
# Analyzing when there are more posts 
sns.histplot(x='post_day' , data =df)
# Based on the plot there are more posts in the middle of the week
# Out:
# <Axes: xlabel='post_day', ylabel='Count'>

# %%
# sentiment score in each platfrom 
sns.countplot(x='sentiment_score' , data=df , hue = 'platform')
# Out:
# <Axes: xlabel='sentiment_score', ylabel='count'>
